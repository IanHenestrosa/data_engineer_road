# %% [markdown]
# # Introdution
# This is going to be my learning process for the Pandas library. I’ll learn how to explore, clean, and process data. I’ll go through the documentation and watch some tutorials on YouTube. In addition, I’ll reinforce this knowledge with exercises on LeetCode.

# %% [markdown]
# ## How to read and write tabular data?
# The ability to import data from each of these data sources is provided by functions with the prefix, `read_*`. Similarly, the `to_*` methods are used to store data.

# %%
import pandas as pd

# %%
titanic_data = pd.read_csv('data/titanic_data.csv')
titanic_data

# %% [markdown]
# If I want to see the first 8 rows or de last 5 rows of a Pandas DataFrame.

# %%
titanic_data.head(8)

# %%
titanic_data.tail(5)

# %% [markdown]
# If I want to checkout the details of the data types and how pandas interpreted this columns.

# %%
titanic_data.dtypes

# %% [markdown]
# If I need to save the titanic data set into an Excel Worsheet.

# %%
titanic_data.to_excel('data/titanic_data.xlsx', sheet_name='passengers', index=False)
titanic_data.to_excel('data/titanic_data_index.xlsx', sheet_name='passengers', index=True)
